# %% [markdown]
# <a href="https://colab.research.google.com/github/ysur0004-yuwan/Workshop1-Commenting/blob/main/pDOC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ysur0004-yuwan/Workshop1-Commenting.git
# %cd Workshop1-Commenting

# !pip install pdoc
# !pdoc ./your_file.py -o ./docs

# !git add docs
# !git commit -m "Add generated documentation"
# !git push
# Out:
# Cloning into 'Workshop1-Commenting'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 30 (delta 13), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (30/30), 11.97 KiB | 207.00 KiB/s, done.
# Resolving deltas: 100% (13/13), done.
# /content/Workshop1-Commenting
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 5.6 MB/s eta 0:00:00
# ...
# Warn: Cannot find spec for your_file (from ./your_file.py):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pdoc/extract.py", line 63, in walk_specs
#     raise ModuleNotFoundError(modname)
# ModuleNotFoundError: your_file
#  (/usr/local/lib/python3.12/dist-packages/pdoc/__init__.py:544)
# Traceback (most recent call last):
#   File "/usr/local/bin/pdoc", line 8, in <module>
#     sys.exit(cli())
# ...
